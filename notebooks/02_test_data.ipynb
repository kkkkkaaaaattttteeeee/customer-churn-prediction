# %% [markdown]
# # %% [markdown]
# # # Тестирование модуля предобработки данных
#
# # %%
# # Добавляем src в путь для импорта
# import sys
# import os
# sys.path.append('../src')
#
# # %%
# # Пробуем импортировать наш модуль
# try:
#     from data import preprocessing
#     print("✅ Модуль preprocessing успешно импортирован")
# except Exception as e:
#     print(f"❌ Ошибка импорта: {e}")
#
# # %%
# # Тестируем загрузку данных
# print("Тест 1: Загрузка данных")
# data_path = '../data/raw/sample_data.csv'
#
# if os.path.exists(data_path):
#     print(f"Файл найден: {data_path}")
#
#     # Создаем экземпляр или вызываем функцию
#     result = preprocessing.load_data(data_path)
#     print(f"Результат: {type(result)}")
#
#     if result is not None:
#         print("\nВызов анализа данных:")
#         preprocessing.analyze_data(result)
# else:
#     print(f"Файл не найден: {data_path}")
#
# # %%
# # Проверяем структуру проекта
# print("\nСтруктура проекта:")
# for root, dirs, files in os.walk('..'):
#     level = root.replace('..', '').count(os.sep)
#     indent = ' ' * 2 * level
#     print(f"{indent}{os.path.basename(root)}/")
#     subindent = ' ' * 2 * (level + 1)
#     for file in files[:5]:  # Показываем только первые 5 файлов в каждой папке
#         if not file.startswith('.'):  # Пропускаем скрытые файлы
#             print(f"{subindent}{file}")
